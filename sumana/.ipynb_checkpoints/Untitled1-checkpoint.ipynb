# %%
import json
# from pprint import pprint

data = json.load(open('customgeo.json'))
# Out:
# [{'geometry': {'coordinates': [[[1.707006470000067, 42.5027814740001],
#      [1.697498006000075, 42.49446156900012],
#      [1.68633589600006, 42.49061167500008],
#      [1.674243611000065, 42.49050832100005],
#      [1.662358032000043, 42.493712260000024],
#      [1.659774210000137, 42.49681284600007],
#      [1.656983683000078, 42.49763966900008],
#      [1.653986450000048, 42.4965286260001],
#      [1.650369100000063, 42.49340220200014],
#      [1.639517049000119, 42.46642710400002],
#      [1.607477661000104, 42.456427714000085],
#      [1.544432414000084, 42.45035573400014],
#      [1.538851359000063, 42.44565317800007],
#      [1.534510539000081, 42.43991709400009],
#      [1.528206014000091, 42.43423268600006],
#      [1.516630493000122, 42.42950429300009],
#      [1.508465617000127, 42.42867747000005],
#      [1.447900838000066, 42.43464609800009],
#      [1.436428670000055, 42.44095062300008],
#      [1.436428670000055, 42.4534821580001],
# ...

# %%
len(data['features'])
# Out:
# 38

# %%
for i in range(0, len(data['features']):
    
    print(data['features'][i]);
# Out:
#   File "<ipython-input-13-f2e4a4801274>", line 1
#     for i in range(0, len(data['features']):
#                                            ^
# SyntaxError: invalid syntax
