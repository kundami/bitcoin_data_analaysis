# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('Trade_over_2Y.csv')

# %%
df.head()
# Out:
#          Country Codes  Avg_Trade_per_min  Exchange_count   Latitude  \
# 0          Japan   JPN               8.30               3  36.204824
# 1      Indonesia   IDN               4.93               1  -0.789275
# 2         Russia   RUS               3.16               2  61.524010
# 3  United States   USA               3.06              23  37.090240
# 4          China   CHN               1.90               5  35.861660
#
#     Longitude               Currency
# 0  138.252924           Japanese yen
# 1  113.921327      Indonesian rupiah
# 2  105.318756          Russian ruble
# 3  -95.712891              US Dollar
# 4  104.195397  Chinese Yuan Renminbi

# %%
df=df.drop(df.columns[[1,4,5,6]], axis=1)

df
# Out:
#                  Country  Avg_Trade_per_min  Exchange_count
# 0                  Japan               8.30               3
# 1              Indonesia               4.93               1
# 2                 Russia               3.16               2
# 3          United States               3.06              23
# 4                  China               1.90               5
# 5         European Union               1.74              19
# 6         United Kingdom               1.08               5
# 7                 Brazil               0.87               2
# 8                 Mexico               0.75               2
# 9              Venezuela               0.56               1
# 10                Poland               0.53               5
# 11             Australia               0.51               2
# 12               Ukraine               0.27               2
# 13                Canada               0.23               6
# 14                 India               0.15               1
# ...

# %%
dv = pd.read_csv('Volume_over_2Y.csv')

# %%
dv=dv.drop(dv.columns[[1,3,4,5,6,7,8,9,10,11]], axis=1)

dv
# Out:
#                  Country                                       Trade_Volume
# 0          United States  4199439166822440000000000000000000000000000000...
# 1         European Union  6240000000000000000000000000000000000000000000...
# 2                  China        1443628445320690000000000000000000000000000
# 3         United Kingdom                      41600000000000000000000000000
# 4                 Canada                          3090000000000000000000000
# 5                 Poland                             3580000000000000000000
# 6                  Japan                                 512609309114671000
# 7                 Russia                                       200000000000
# 8              Australia                                        22596183431
# 9                 Brazil                                        18464810423
# 10             Singapore                                         2177373768
# ...

# %%
new_df=pd.merge(df, dv, on='Country')

# %%
new_df
# Out:
#                  Country  Avg_Trade_per_min  Exchange_count  \
# 0                  Japan               8.30               3
# 1              Indonesia               4.93               1
# 2                 Russia               3.16               2
# 3          United States               3.06              23
# 4                  China               1.90               5
# 5         European Union               1.74              19
# 6         United Kingdom               1.08               5
# 7                 Brazil               0.87               2
# 8                 Mexico               0.75               2
# 9              Venezuela               0.56               1
# 10                Poland               0.53               5
# 11             Australia               0.51               2
# 12               Ukraine               0.27               2
# 13                Canada               0.23               6
# 14                 India               0.15               1
# ...

# %%
new_df.to_csv("d3file.csv")
